# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.integrate as integrate

x = np.linspace(0, 1, 100)
y = np.sqrt( 1**2 - x**2 )

plt.figure(figsize=(5,5))
plt.plot(x,y)

# %%
result = integrate.quad(lambda i: np.sqrt( 1**2 - i**2 ), 0,1)
result[0] * 4
# Out:
# 3.1415926535897922
